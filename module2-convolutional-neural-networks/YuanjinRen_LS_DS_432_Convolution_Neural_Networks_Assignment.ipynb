# %% [markdown]
# <a href="https://colab.research.google.com/github/yuanjinren/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/YuanjinRen_LS_DS_432_Convolution_Neural_Networks_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Assignment 2*
# # Convolutional Neural Networks (CNNs)

# %% [markdown]
# # Assignment
#
# - <a href="#p1">Part 1:</a> Pre-Trained Model
# - <a href="#p2">Part 2:</a> Custom CNN Model
# - <a href="#p3">Part 3:</a> CNN with Data Augmentation
#
#
# You will apply three different CNN models to a binary image classification model using Keras. Classify images of Mountains (`./data/train/mountain/*`) and images of forests (`./data/train/forest/*`). Treat mountains as the positive class (1) and the forest images as the negative (zero).
#
# |Mountain (+)|Forest (-)|
# |---|---|
# |![](https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data/train/mountain/art1131.jpg?raw=1)|![](https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data/validation/forest/cdmc317.jpg?raw=1)|
#
# The problem is relatively difficult given that the sample is tiny: there are about 350 observations per class. This sample size might be something that you can expect with prototyping an image classification problem/solution at work. Get accustomed to evaluating several different possible models.

# %% [markdown]
# # Pre - Trained Model
# <a id="p1"></a>
#
# Load a pretrained network from Keras, [ResNet50](https://tfhub.dev/google/imagenet/resnet_v1_50/classification/1) - a 50 layer deep network trained to recognize [1000 objects](https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt). Starting usage:
#
# ```python
# import numpy as np
#
# from tensorflow.keras.applications.resnet50 import ResNet50
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
#
# from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
# from tensorflow.keras.models import Model # This is the functional API
#
# resnet = ResNet50(weights='imagenet', include_top=False)
#
# ```
#
# The `include_top` parameter in `ResNet50` will remove the full connected layers from the ResNet model. The next step is to turn off the training of the ResNet layers. We want to use the learned parameters without updating them in future training passes.
#
# ```python
# for layer in resnet.layers:
#     layer.trainable = False
# ```
#
# Using the Keras functional API, we will need to additional additional full connected layers to our model. We we removed the top layers, we removed all preivous fully connected layers. In other words, we kept only the feature processing portions of our network. You can expert with additional layers beyond what's listed here. The `GlobalAveragePooling2D` layer functions as a really fancy flatten function by taking the average of each of the last convolutional layer outputs (which is two dimensional still).
#
# ```python
# x = resnet.output
# x = GlobalAveragePooling2D()(x) # This layer is a really fancy flatten
# x = Dense(1024, activation='relu')(x)
# predictions = Dense(1, activation='sigmoid')(x)
# model = Model(resnet.input, predictions)
# ```
#
# Your assignment is to apply the transfer learning above to classify images of Mountains (`./data/train/mountain/*`) and images of forests (`./data/train/forest/*`). Treat mountains as the positive class (1) and the forest images as the negative (zero).
#
# Steps to complete assignment:
# 1. Load in Image Data into numpy arrays (`X`)
# 2. Create a `y` for the labels
# 3. Train your model with pre-trained layers from resnet
# 4. Report your model's accuracy

# %% [markdown]
# ## Load in Data
#
# This surprisingly more difficult than it seems, because you are working with directories of images instead of a single file. This boiler plate will help you download a zipped version of the directory of images. The directory is organized into "train" and "validation" which you can use inside an `ImageGenerator` class to stream batches of images thru your model.

# %% [markdown]
# ### Download & Summarize the Data
#
# This step is completed for you. Just run the cells and review the results.

# %%
import tensorflow as tf
import os

_URL = 'https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data.zip?raw=true'

path_to_zip = tf.keras.utils.get_file('./data.zip', origin=_URL, extract=True)
PATH = os.path.join(os.path.dirname(path_to_zip), 'data')
# Out:
# Downloading data from https://github.com/LambdaSchool/DS-Unit-4-Sprint-3-Deep-Learning/blob/main/module2-convolutional-neural-networks/data.zip?raw=true
# 42172416/42170838 [==============================] - 1s 0us/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

# %%
train_mountain_dir = os.path.join(train_dir, 'mountain')  # directory with our training cat pictures
train_forest_dir = os.path.join(train_dir, 'forest')  # directory with our training dog pictures
validation_mountain_dir = os.path.join(validation_dir, 'mountain')  # directory with our validation cat pictures
validation_forest_dir = os.path.join(validation_dir, 'forest')  # directory with our validation dog pictures

# %%
num_mountain_tr = len(os.listdir(train_mountain_dir))
num_forest_tr = len(os.listdir(train_forest_dir))

num_mountain_val = len(os.listdir(validation_mountain_dir))
num_forest_val = len(os.listdir(validation_forest_dir))

total_train = num_mountain_tr + num_forest_tr
total_val = num_mountain_val + num_forest_val

# %%
print('total training mountain images:', num_mountain_tr)
print('total training forest images:', num_forest_tr)

print('total validation mountain images:', num_mountain_val)
print('total validation forest images:', num_forest_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training mountain images: 254
# total training forest images: 270
# total validation mountain images: 125
# total validation forest images: 62
# --
# Total training images: 524
# Total validation images: 187

# %% [markdown]
# ### Keras `ImageGenerator` to Process the Data
#
# This step is completed for you, but please review the code. The `ImageGenerator` class reads in batches of data from a directory and pass them to the model one batch at a time. Just like large text files, this method is advantageous, because it stifles the need to load a bunch of images into memory.
#
# Check out the documentation for this class method: [Keras `ImageGenerator` Class](https://keras.io/preprocessing/image/#imagedatagenerator-class). You'll expand it's use in the third assignment objective.

# %%
batch_size = 16
epochs = 50
IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our training data
validation_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our validation data

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                           class_mode='binary')
# Out:
# Found 533 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=batch_size,
                                                              directory=validation_dir,
                                                              target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                              class_mode='binary')
# Out:
# Found 195 images belonging to 2 classes.

# %%
from skimage.io import imread_collection

# my path 
col_forest = '/content/drive/My Drive/data/train/forest/*.jpg'
col_mountain = '/content/drive/My Drive/data/train/mountain/*.jpg'

# creating a collection with the available images
collect_f = imread_collection(col_forest)
collect_m = imread_collection(col_mountain)

# %%
collect_f[0].shape
# Out:
# (256, 256, 3)

# %%
collect_f[0]
# Out:
# array([[[ 3,  0,  0],
#         [ 5,  1,  0],
#         [ 6,  0,  0],
#         ...,
#         [ 0,  0, 10],
#         [10, 10, 20],
#         [ 0,  0,  9]],
#
#        [[ 3,  0,  0],
#         [ 7,  1,  1],
#         [ 8,  0,  0],
#         ...,
#         [11, 12, 17],
#         [ 3,  4,  9],
#         [ 0,  1,  6]],
#
#        [[ 5,  0,  0],
#         [ 9,  1,  0],
#         [10,  0,  0],
#         ...,
#         [ 0,  1,  3],
#         [ 0,  0,  2],
#         [ 4,  4,  6]],
#
#        ...,
#
#        [[ 2,  0,  1],
#         [13, 11, 12],
#         [ 6,  4,  5],
#         ...,
#         [14,  5,  0],
#         [ 8,  1,  0],
#         [11,  3,  0]],
#
#        [[ 1,  2,  6],
#         [ 2,  3,  7],
#         [ 0,  0,  5],
#         ...,
#         [ 4,  0,  0],
#         [ 5,  1,  0],
#         [ 4,  0,  0]],
#
#        [[ 0,  1,  6],
#         [ 0,  0,  8],
#         [ 2,  5, 12],
#         ...,
#         [ 1,  1,  0],
#         [ 2,  2,  2],
#         [ 1,  1,  3]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))
for i in range(5):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(collect_f[i], cmap=plt.cm.binary)
plt.show()

plt.figure(figsize=(20,20))
for i in range(5):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(collect_m[i], cmap=plt.cm.binary)
plt.show()

# %% [markdown]
# ## Instatiate Model

# %%
import numpy as np
 
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
 
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model # This is the functional API
 
resnet = ResNet50(weights='imagenet', include_top=False)

# %%
for layer in resnet.layers:
    layer.trainable = False

# %%
x = resnet.output
x = GlobalAveragePooling2D()(x) # This layer is a really fancy flatten
x = Dense(1024, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(resnet.input, predictions)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_data_gen,
    steps_per_epoch=total_train // batch_size,
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=total_val // batch_size
)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 104s 3s/step - loss: 0.7410 - accuracy: 0.5749 - val_loss: 0.7338 - val_accuracy: 0.3920
# Epoch 2/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.5778 - accuracy: 0.7066 - val_loss: 0.5484 - val_accuracy: 0.7614
# Epoch 3/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.5013 - accuracy: 0.7725 - val_loss: 0.8107 - val_accuracy: 0.4489
# Epoch 4/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.4789 - accuracy: 0.7665 - val_loss: 0.4640 - val_accuracy: 0.8125
# Epoch 5/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.4144 - accuracy: 0.8543 - val_loss: 0.4195 - val_accuracy: 0.8466
# Epoch 6/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.4077 - accuracy: 0.8204 - val_loss: 0.5314 - val_accuracy: 0.7557
# Epoch 7/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.4298 - accuracy: 0.8044 - val_loss: 0.4029 - val_accuracy: 0.7727
# Epoch 8/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.4026 - accuracy: 0.7984 - val_loss: 0.3238 - val_accuracy: 0.9148
# Epoch 9/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.3079 - accuracy: 0.8882 - val_loss: 0.6163 - val_accuracy: 0.6705
# Epoch 10/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.3006 - accuracy: 0.8982 - val_loss: 0.3400 - val_accuracy: 0.8523
# Epoch 11/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.2931 - accuracy: 0.8782 - val_loss: 0.5127 - val_accuracy: 0.7898
# Epoch 12/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.3840 - accuracy: 0.8224 - val_loss: 0.3027 - val_accuracy: 0.8750
# Epoch 13/50
# 32/32 [==============================] - 101s 3s/step - loss: 0.3365 - accuracy: 0.8443 - val_loss: 0.3914 - val_accuracy: 0.8466
# Epoch 14/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.2357 - accuracy: 0.9162 - val_loss: 0.2747 - val_accuracy: 0.8977
# Epoch 15/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.2363 - accuracy: 0.9142 - val_loss: 0.4384 - val_accuracy: 0.8239
# Epoch 16/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.2222 - accuracy: 0.9261 - val_loss: 0.2697 - val_accuracy: 0.8807
# Epoch 17/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1971 - accuracy: 0.9381 - val_loss: 0.3321 - val_accuracy: 0.8636
# Epoch 18/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1970 - accuracy: 0.9381 - val_loss: 0.2658 - val_accuracy: 0.8920
# Epoch 19/50
# 32/32 [==============================] - 101s 3s/step - loss: 0.1777 - accuracy: 0.9521 - val_loss: 0.2301 - val_accuracy: 0.9375
# Epoch 20/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1568 - accuracy: 0.9541 - val_loss: 0.3479 - val_accuracy: 0.8523
# Epoch 21/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.2780 - accuracy: 0.8683 - val_loss: 0.2300 - val_accuracy: 0.9261
# Epoch 22/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1922 - accuracy: 0.9281 - val_loss: 0.3357 - val_accuracy: 0.8523
# Epoch 23/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1468 - accuracy: 0.9541 - val_loss: 0.2030 - val_accuracy: 0.9261
# Epoch 24/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1881 - accuracy: 0.9341 - val_loss: 0.3086 - val_accuracy: 0.8580
# Epoch 25/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.1441 - accuracy: 0.9570 - val_loss: 0.2524 - val_accuracy: 0.9148
# Epoch 26/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1512 - accuracy: 0.9441 - val_loss: 0.2347 - val_accuracy: 0.9261
# Epoch 27/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1509 - accuracy: 0.9461 - val_loss: 0.2289 - val_accuracy: 0.9261
# Epoch 28/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1386 - accuracy: 0.9541 - val_loss: 0.2251 - val_accuracy: 0.9261
# Epoch 29/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1250 - accuracy: 0.9501 - val_loss: 0.3237 - val_accuracy: 0.8750
# Epoch 30/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1295 - accuracy: 0.9541 - val_loss: 0.2702 - val_accuracy: 0.9034
# Epoch 31/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.1049 - accuracy: 0.9661 - val_loss: 0.2192 - val_accuracy: 0.9375
# Epoch 32/50
# 32/32 [==============================] - 100s 3s/step - loss: 0.1024 - accuracy: 0.9701 - val_loss: 0.2004 - val_accuracy: 0.9375
# Epoch 33/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.1259 - accuracy: 0.9541 - val_loss: 0.2093 - val_accuracy: 0.9375
# Epoch 34/50
# 32/32 [==============================] - 100s 3s/step - loss: 0.1400 - accuracy: 0.9501 - val_loss: 0.1891 - val_accuracy: 0.9375
# Epoch 35/50
# 32/32 [==============================] - 98s 3s/step - loss: 0.0962 - accuracy: 0.9681 - val_loss: 0.2247 - val_accuracy: 0.9205
# Epoch 36/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.1178 - accuracy: 0.9561 - val_loss: 0.3678 - val_accuracy: 0.8636
# Epoch 37/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.1138 - accuracy: 0.9561 - val_loss: 0.2019 - val_accuracy: 0.9318
# Epoch 38/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.1037 - accuracy: 0.9641 - val_loss: 0.2155 - val_accuracy: 0.9205
# Epoch 39/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.1685 - accuracy: 0.9242 - val_loss: 0.3143 - val_accuracy: 0.8750
# Epoch 40/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.1007 - accuracy: 0.9601 - val_loss: 0.1918 - val_accuracy: 0.9375
# Epoch 41/50
# 32/32 [==============================] - 101s 3s/step - loss: 0.0826 - accuracy: 0.9785 - val_loss: 0.6410 - val_accuracy: 0.7614
# Epoch 42/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.1081 - accuracy: 0.9541 - val_loss: 0.2097 - val_accuracy: 0.9318
# Epoch 43/50
# 32/32 [==============================] - 106s 3s/step - loss: 0.0736 - accuracy: 0.9840 - val_loss: 0.1423 - val_accuracy: 0.9489
# Epoch 44/50
# 32/32 [==============================] - 100s 3s/step - loss: 0.1545 - accuracy: 0.9281 - val_loss: 0.3125 - val_accuracy: 0.8807
# Epoch 45/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.1328 - accuracy: 0.9381 - val_loss: 0.3930 - val_accuracy: 0.8523
# Epoch 46/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.1453 - accuracy: 0.9401 - val_loss: 0.3588 - val_accuracy: 0.8580
# Epoch 47/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.2141 - accuracy: 0.9142 - val_loss: 0.2073 - val_accuracy: 0.9489
# Epoch 48/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.1034 - accuracy: 0.9501 - val_loss: 0.1855 - val_accuracy: 0.9489
# Epoch 49/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0935 - accuracy: 0.9581 - val_loss: 0.5461 - val_accuracy: 0.8068
# Epoch 50/50
# 32/32 [==============================] - 99s 3s/step - loss: 0.1481 - accuracy: 0.9461 - val_loss: 0.3467 - val_accuracy: 0.8750

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Val'], loc='upper right')
plt.show();

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Val'], loc='upper right')
plt.show();

# %% [markdown]
# # load tensorflow hub to train the model

# %%
import tensorflow_hub as hub
model = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/tensorflow/resnet_50/feature_vector/1",
                   trainable=False),  # Can be True, see below.
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.build([None, 224, 224, 3])  # Batch input shape.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_1 (KerasLayer)   (None, 2048)              23561152
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 23,563,201
# Trainable params: 2,049
# Non-trainable params: 23,561,152
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_data_gen,
    steps_per_epoch=total_train // batch_size,
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=total_val // batch_size
)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.3063 - accuracy: 0.8942 - val_loss: 0.1051 - val_accuracy: 0.9943
# Epoch 2/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0777 - accuracy: 0.9900 - val_loss: 0.0619 - val_accuracy: 1.0000
# Epoch 3/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0467 - accuracy: 0.9960 - val_loss: 0.0384 - val_accuracy: 1.0000
# Epoch 4/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0364 - accuracy: 0.9940 - val_loss: 0.0308 - val_accuracy: 1.0000
# Epoch 5/50
# 32/32 [==============================] - 107s 3s/step - loss: 0.0298 - accuracy: 0.9980 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 6/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0245 - accuracy: 0.9980 - val_loss: 0.0273 - val_accuracy: 1.0000
# Epoch 7/50
# 32/32 [==============================] - 104s 3s/step - loss: 0.0206 - accuracy: 0.9980 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 8/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0178 - accuracy: 0.9980 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 9/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 10/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 11/50
# 32/32 [==============================] - 105s 3s/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 12/50
# 32/32 [==============================] - 104s 3s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 1.0000
# Epoch 13/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 14/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 15/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 16/50
# 32/32 [==============================] - 106s 3s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 17/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 18/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 19/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 20/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 21/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 22/50
# 32/32 [==============================] - 106s 3s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 23/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 24/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 25/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 26/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 27/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 28/50
# 32/32 [==============================] - 106s 3s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 29/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 30/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 31/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 32/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 33/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 34/50
# 32/32 [==============================] - 106s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 35/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 36/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 37/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 38/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 39/50
# 32/32 [==============================] - 106s 3s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 40/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 41/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 42/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 43/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 44/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 45/50
# 32/32 [==============================] - 106s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 46/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 47/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 48/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 49/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 50/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000

# %% [markdown]
# # Custom CNN Model
#
# In this step, write and train your own convolutional neural network using Keras. You can use any architecture that suits you as long as it has at least one convolutional and one pooling layer at the beginning of the network - you can add more if you want.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# %%
# Define the Model
custom_model = Sequential()

custom_model.add(Conv2D(16, (3,3), activation='relu', input_shape=(224, 224, 3)))
custom_model.add(MaxPooling2D((2,2)))
custom_model.add(Dropout(0.2))

custom_model.add(Conv2D(32, (3,3), activation='relu'))
custom_model.add(MaxPooling2D((2,2)))
custom_model.add(Dropout(0.2))

custom_model.add(Conv2D(32, (3,3), activation='relu'))
custom_model.add(Flatten())
custom_model.add(Dense(32, activation='relu'))
custom_model.add(Dropout(0.2))

custom_model.add(Dense(1, activation='sigmoid'))

custom_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 32)        9248
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2768928
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,783,297
# Trainable params: 2,783,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile Model
custom_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fit Model
hist = custom_model.fit(train_data_gen, 
                        epochs=10, 
                        validation_data=val_data_gen)
# Out:
# Epoch 1/10
# 34/34 [==============================] - 25s 732ms/step - loss: 0.0411 - accuracy: 0.9869 - val_loss: 0.4545 - val_accuracy: 0.8615
# Epoch 2/10
# 34/34 [==============================] - 25s 732ms/step - loss: 0.0222 - accuracy: 0.9944 - val_loss: 0.3736 - val_accuracy: 0.8974
# Epoch 3/10
# 34/34 [==============================] - 25s 733ms/step - loss: 0.0195 - accuracy: 0.9925 - val_loss: 0.3166 - val_accuracy: 0.9179
# Epoch 4/10
# 34/34 [==============================] - 28s 837ms/step - loss: 0.0285 - accuracy: 0.9850 - val_loss: 0.2148 - val_accuracy: 0.9385
# Epoch 5/10
# 34/34 [==============================] - 25s 734ms/step - loss: 0.0529 - accuracy: 0.9831 - val_loss: 0.2064 - val_accuracy: 0.9077
# Epoch 6/10
# 34/34 [==============================] - 25s 736ms/step - loss: 0.0941 - accuracy: 0.9625 - val_loss: 0.1202 - val_accuracy: 0.9333
# Epoch 7/10
# 34/34 [==============================] - 25s 736ms/step - loss: 0.0449 - accuracy: 0.9906 - val_loss: 0.4362 - val_accuracy: 0.8718
# Epoch 8/10
# 34/34 [==============================] - 25s 736ms/step - loss: 0.0102 - accuracy: 0.9962 - val_loss: 0.2718 - val_accuracy: 0.9128
# Epoch 9/10
# 34/34 [==============================] - 25s 735ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.5402 - val_accuracy: 0.8821
# Epoch 10/10
# 34/34 [==============================] - 25s 734ms/step - loss: 0.0029 - accuracy: 0.9981 - val_loss: 0.4706 - val_accuracy: 0.9077

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show();

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show();

# %% [markdown]
# # Custom CNN Model with Image Manipulations
#
# To simulate an increase in a sample of image, you can apply image manipulation techniques: cropping, rotation, stretching, etc. Luckily Keras has some handy functions for us to apply these techniques to our mountain and forest example. Simply, you should be able to modify our image generator for the problem. Check out these resources to help you get started:
#
# 1. [Keras `ImageGenerator` Class](https://keras.io/preprocessing/image/#imagedatagenerator-class)
# 2. [Building a powerful image classifier with very little data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html)

# %%
from keras.preprocessing.image import ImageDataGenerator,array_to_img, img_to_array, load_img

datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
img = load_img('/content/drive/My Drive/data/train/forest/for102.jpg')  # this is a PIL image
x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory
i = 0
for batch in datagen.flow(x, batch_size=1,
                          save_to_dir='/content/drive/My Drive/data/train/forest', save_prefix='for102', save_format='jpeg'):
    i += 1
    if i > 20:
        break  # otherwise the generator would loop indefinitely

# %%
from skimage.io import imread_collection
col_dir = '/content/drive/My Drive/data/train/forest/*.jpeg'
col = imread_collection(col_dir)

# %%
plt.figure(figsize=(15, 15))
for i in range(20):
  plt.subplot(5, 5, i+1)
  plt.imshow(col[i], cmap=plt.cm.binary)
plt.show();

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
train_gen = train_datagen.flow_from_directory(batch_size=batch_size,
                                              directory=train_dir,
                                              shuffle=True,
                                              target_size=(IMG_HEIGHT, IMG_WIDTH),
                                              class_mode='binary')
val_gen = test_datagen.flow_from_directory(batch_size=batch_size,
                                              directory=train_dir,
                                              shuffle=True,
                                              target_size=(IMG_HEIGHT, IMG_WIDTH),
                                              class_mode='binary')
# Out:
# Found 533 images belonging to 2 classes.
# Found 533 images belonging to 2 classes.

# %%
# Define the Model
aug_model = Sequential()

aug_model.add(Conv2D(16, (3,3), activation='relu', input_shape=(224, 224, 3)))
aug_model.add(MaxPooling2D((2,2)))


aug_model.add(Conv2D(32, (3,3), activation='relu'))
aug_model.add(MaxPooling2D((2,2)))
# aug_model.add(Dropout(0.2))

aug_model.add(Conv2D(32, (3,3), activation='relu'))
aug_model.add(Flatten())
aug_model.add(Dense(32, activation='relu'))
aug_model.add(Dropout(0.2))

aug_model.add(Dense(1, activation='sigmoid'))

aug_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 109, 109, 32)      4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 52, 52, 32)        9248
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 86528)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2768928
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,783,297
# Trainable params: 2,783,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
aug_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %%
aug_hist = aug_model.fit(train_gen,
                         epochs=10,
                         validation_data=val_gen)
# Out:
# Epoch 1/10
# 34/34 [==============================] - 34s 1s/step - loss: 0.8304 - accuracy: 0.6567 - val_loss: 0.2849 - val_accuracy: 0.9212
# Epoch 2/10
# 34/34 [==============================] - 34s 991ms/step - loss: 0.3673 - accuracy: 0.8649 - val_loss: 0.1789 - val_accuracy: 0.9325
# Epoch 3/10
# 34/34 [==============================] - 34s 991ms/step - loss: 0.2809 - accuracy: 0.8818 - val_loss: 0.1762 - val_accuracy: 0.9400
# Epoch 4/10
# 34/34 [==============================] - 34s 997ms/step - loss: 0.2935 - accuracy: 0.8987 - val_loss: 0.3212 - val_accuracy: 0.8743
# Epoch 5/10
# 34/34 [==============================] - 34s 989ms/step - loss: 0.2845 - accuracy: 0.9006 - val_loss: 0.5224 - val_accuracy: 0.8180
# Epoch 6/10
# 34/34 [==============================] - 34s 1s/step - loss: 0.2751 - accuracy: 0.9006 - val_loss: 0.2736 - val_accuracy: 0.8743
# Epoch 7/10
# 34/34 [==============================] - 34s 987ms/step - loss: 0.2502 - accuracy: 0.9006 - val_loss: 0.1681 - val_accuracy: 0.9381
# Epoch 8/10
# 34/34 [==============================] - 34s 1s/step - loss: 0.2301 - accuracy: 0.9156 - val_loss: 0.1539 - val_accuracy: 0.9381
# Epoch 9/10
# 34/34 [==============================] - 34s 999ms/step - loss: 0.2019 - accuracy: 0.9250 - val_loss: 0.2519 - val_accuracy: 0.8593
# Epoch 10/10
# 34/34 [==============================] - 34s 987ms/step - loss: 0.2043 - accuracy: 0.9231 - val_loss: 0.4772 - val_accuracy: 0.8180

# %%
aug_model.save_weights('aug_model.h5')

# %%
plt.plot(aug_hist.history['accuracy'])
plt.plot(aug_hist.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show();

# %% [markdown]
# # Resources and Stretch Goals
#
# Stretch goals
# - Enhance your code to use classes/functions and accept terms to search and classes to look for in recognizing the downloaded images (e.g. download images of parties, recognize all that contain balloons)
# - Check out [other available pretrained networks](https://tfhub.dev), try some and compare
# - Image recognition/classification is somewhat solved, but *relationships* between entities and describing an image is not - check out some of the extended resources (e.g. [Visual Genome](https://visualgenome.org/)) on the topic
# - Transfer learning - using images you source yourself, [retrain a classifier](https://www.tensorflow.org/hub/tutorials/image_retraining) with a new category
# - (Not CNN related) Use [piexif](https://pypi.org/project/piexif/) to check out the metadata of images passed in to your system - see if they're from a national park! (Note - many images lack GPS metadata, so this won't work in most cases, but still cool)
#
# Resources
# - [Deep Residual Learning for Image Recognition](https://arxiv.org/abs/1512.03385) - influential paper (introduced ResNet)
# - [YOLO: Real-Time Object Detection](https://pjreddie.com/darknet/yolo/) - an influential convolution based object detection system, focused on inference speed (for applications to e.g. self driving vehicles)
# - [R-CNN, Fast R-CNN, Faster R-CNN, YOLO](https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e) - comparison of object detection systems
# - [Common Objects in Context](http://cocodataset.org/) - a large-scale object detection, segmentation, and captioning dataset
# - [Visual Genome](https://visualgenome.org/) - a dataset, a knowledge base, an ongoing effort to connect structured image concepts to language
